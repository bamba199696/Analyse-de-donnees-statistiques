# %% [markdown]
# # L'analyse exploratoire des données

# %% [markdown]
# Organiser, tracer et synthétiser les données d'un dataset

# %% [markdown]
# “Exploratory data analysis can never be the
# whole story, but nothing else can serve as the
# foundation stone.”
#
# —John Tukey

# %% [markdown]
# Résultats des élections aux États-Unis en 2008

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Que peut-on dire sur la moyenne des votes pour obama? N'est ce pas suprenant ?

# %% [markdown]
# Pour un histogramme, le choix du nombre de barres est important. Cela change le rendu visuel.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Plusieurs façons de paramétrer le nombre de barres
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Seaborn = Un excellent module de visualisation écrit par Michael Waskom

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Tracer un histogramme des données de l'iris

# %% [markdown]
# Pour les exercices de cette section, vous utiliserez un ensemble de données classique collecté par le botaniste Edward Anderson et rendu célèbre par Ronald Fisher, l'un des statisticiens les plus prolifiques de l'histoire.
#
# Anderson a soigneusement mesuré les propriétés anatomiques d'échantillons de trois espèces différentes d'iris, Iris setosa, Iris versicolor et Iris virginica. L'ensemble de données complet est disponible dans  scikit-learn. Ici, vous travaillerez avec ses mesures de longueur de pétale.
#
# Tracez un histogramme de la longueur des pétales de ses 50 échantillons d'Iris versicolor en utilisant les paramètres par défaut de matplotlib / seaborn. Pour spécifier le style seaborn par défaut, vous pouvez utiliser sns.set (), où sns est l'alias sous lequel seaborn est importé.
#
# Le sous-ensemble de l'ensemble de données contenant les longueurs des pétales d'Iris versicolor en unités de centimètres (cm) est stocké dans le tableau NumPy versicolor_petal_length.

# %%
import numpy as np

versicolor_petal_length = np.array([4.7,  4.5,  4.9,  4.,  4.6,  4.5,  4.7,  3.3,  4.6,  3.9,  3.5,
                                    4.2,  4.,  4.7,  3.6,  4.4,  4.5,  4.1,  4.5,  3.9,  4.8,  4.,
                                    4.9,  4.7,  4.3,  4.4,  4.8,  5.,  4.5,  3.5,  3.8,  3.7,  3.9,
                                    5.1,  4.5,  4.5,  4.7,  4.4,  4.1,  4.,  4.4,  4.6,  4.,  3.3,
                                    4.2,  4.2,  4.2,  4.3,  3.,  4.1])

# %%
#Importer matplotlib.pyplot et seaborn avec les alias habituels (plt et sns)

# %%
## Définir le style Seaborn par défaut

# %%
#Tracer un histogramme des longueurs des pétales d'Iris versicolor en utilisant plt.hist () et le tableau NumPy fourni versicolor_petal_length.

# %%
#Affichez l'histogramme à l'aide de plt.show ().

# %% [markdown]
# N'oubliez pas que vous devez toujours inclure des unités dans vos étiquettes d'axe. Le libellé de votre axe Y est simplement «Nombre». Votre étiquette sur l'axe des x est «longueur des pétales (cm)». Les unités sont indispensables!
#
# Affichez le tracé construit dans les étapes ci-dessus à l'aide de plt.show ()

# %%
#Ajouter des étiquettes pour les axes

___________
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-69618a64b8cd> in <module>
#       1 #Ajouter des étiquettes pour les axes
#       2
# ----> 3 ___________
#
# NameError: name '___________' is not defined

# %% [markdown]
# Réglage du nombre de barres
#
# L'histogramme que vous venez de faire avait dix barres. C'est la valeur par défaut de matplotlib.
#
# La "square root rule" est une règle empirique couramment utilisée pour choisir le nombre de barres à utiliser.
#
# choisissez le nombre de barres comme étant égal à la racine carrée du nombre d'échantillons.
#
# Tracez à nouveau l'histogramme des longueurs des pétales , cette fois en utilisant la règle ci-dessus.

# %%
# Importer numpy en tant que np. Cela donne accès à la fonction racine carrée, np.sqrt ().

_______

# Déterminer le nombre de points de données dont vous disposez à l'aide de len ().
_______

#Calculer le nombre de casiers à l'aide de la règle de la racine carrée.
_______

#Convertisser le nombre de casiers en un entier à l'aide de la fonction int () intégrée.
_______

# Générer l'histogramme et assurez-vous d'utiliser l'argument du mot clé bins.

# %%
Le biais des histogrammes

Les mêmes données peuvent être interprétées différemment selon le choix du nombre de "bins"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Faites un tracé en essaim d'abeilles (bee swarme plot) des longueurs des pétales d'iris. Votre axe des x doit contenir chacune des trois espèces et l'axe des y les longueurs des pétales.

# %%
import pandas as pd
iris_df = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['species'])

# %%
# affihcer les première lignes du iris_df

# %%
# Créer un bee swarm plot vec les paramètres par défaut de Seaborn
_____

# Étiquetez les axes
_____

# Afficher le plot
_____

# %% [markdown]
# Laquelle des conclusions suivantes pourriez-vous tirer ?

# %% [markdown]
#     Tous les pétales de l'espèce 1 sont plus courts que les pétales de l'espèce 2.
#
#     Les pétales de l'espèce 0 ont une gamme de longueurs plus large que les deux autres espèces.
#
#     Les pétales de l'epèce 2 ont tendance à être les plus longs, et les pétales de l'espèce 0 ont tendance à être les plus courts des trois espèces.
#
#     L'espèce 1 est une combinaison des deux autres espèces.

# %% [markdown]
# # Empirical cumulative distribution function (ECDF)

# %% [markdown]
# Imaginons que nous souhaitions avoir une distribution par état des votes pour Obama.
#
# le bee swam plot sera illisible
#
# on peut le tracer en effectuant une segmentation est / ouest

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Mais ce n'est pas très parlant. Heureusement, on peut utiliser une ECDF! Et ouais ça claque !!!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  Dans 75% des états, Obama a obtenu moins de 50% des votes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Calcul de l'ECDF
#
# Dans cet exercice, vous allez écrire une fonction qui prend en entrée un tableau de données 1D, puis renvoie les valeurs x et y de l'ECDF. Vous utiliserez cette fonction encore et encore tout au long de ce cours.  Les ECDF sont parmi les outils les plus importants de l'analyse statistique. Vous pouvez écrire votre propre fonction, foo (x, y) selon le squelette suivant:
#
# def foo (a, b):
#     "" "Indiquez quelle fonction remplit ici" ""
#     # Calcul effectué ici
#     retourner x, y
#
# La fonction foo () ci-dessus prend deux arguments a et b et retourne deux valeurs x et y.
#
# Pour rappel, l'en-tête de fonction "def foo (a, b):" contient la signature de fonction foo (a, b), qui se compose du nom de la fonction, ainsi que de ses paramètres.

# %% [markdown]
# Définissez une fonction avec la signature ecdf (données). Dans la définition de fonction,
#
# Calculez le nombre de points de données, n, à l'aide de la fonction len ().
#
# Les valeurs x sont les données triées. Utilisez la fonction np.sort () pour effectuer le tri.
#
# Les données y de l'ECDF vont de 1 / n à 1 par incréments également espacés. Vous pouvez le construire en utilisant np.arange ().
#
# N'oubliez pas, cependant, que la valeur finale dans np.arange () n'est pas incluse. Par conséquent, np.arange () devra passer de 1 à n + 1. Assurez-vous de diviser cela par n.
#
# La fonction renvoie les valeurs x et y.

# %%
def ecdf(data):
    """Calcul ECDF pour 1 one-dimensional array """
    # Nombre de point : n
    ____ = ____(____)

    # x-data pour  ECDF: x
    ____ = ____(____)

    # y-data pour ECDF: y
    ____ = ____(____, ____) / n

    return x, y

# %% [markdown]
# Vous allez maintenant utiliser votre fonction ecdf () pour calculer l'ECDF pour la longueur des pétales des fleurs de l'espèce 1.
#
# Vous tracerez ensuite l'ECDF. Rappelez-vous que votre fonction ecdf () renvoie deux tableaux, vous devrez donc les décompresser. Un exemple d'un tel déballage est x, y = foo (data), pour une fonction foo ().

# %% [markdown]
# Utilisez ecdf () pour calculer l'ECDF de versicolor_petal_length. Décomposer la sortie dans x_vers et y_vers.
#
# Tracez l'ECDF avec des points. N'oubliez pas d'inclure marker = '.' et linestyle = 'none' en plus de x_vers et y_vers comme arguments dans plt.plot ().
#
# Étiquetez les axes. Vous pouvez nommer l'axe Y «ECDF».

# %%
# Compute ECDF for versicolor data: x_vers, y_vers
____, ____ = ____(____)

# Generate plot


# Label the axes



# Display the plot

# %% [markdown]
# Les ECDF vous permettent également de comparer deux ou plusieurs distributions (bien que les tracés soient encombrés si vous en avez trop). Ici, vous tracerez des ECDF pour les longueurs de pétales des trois espèces d'iris. Vous avez déjà écrit une fonction pour générer des ECDF afin que vous puissiez l'utiliser à bon escient!
#
# Pour superposer les trois ECDF sur le même tracé, vous pouvez utiliser plt.plot () trois fois, une fois pour chaque ECDF. N'oubliez pas d'inclure marker = '.' et linestyle = 'none' comme arguments dans plt.plot ().

# %%
setosa_petal_length = np.array([1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4,
       1.1, 1.2, 1.5, 1.3, 1.4, 1.7, 1.5, 1.7, 1.5, 1. , 1.7, 1.9, 1.6,
       1.6, 1.5, 1.4, 1.6, 1.6, 1.5, 1.5, 1.4, 1.5, 1.2, 1.3, 1.4, 1.3,
       1.5, 1.3, 1.3, 1.3, 1.6, 1.9, 1.4, 1.6, 1.4, 1.5, 1.4])

virginica_petal_length = np.array([6. , 5.1, 5.9, 5.6, 5.8, 6.6, 4.5, 6.3, 5.8, 6.1, 5.1, 5.3, 5.5,
       5. , 5.1, 5.3, 5.5, 6.7, 6.9, 5. , 5.7, 4.9, 6.7, 4.9, 5.7, 6. ,
       4.8, 4.9, 5.6, 5.8, 6.1, 6.4, 5.6, 5.1, 5.6, 6.1, 5.6, 5.5, 4.8,
       5.4, 5.6, 5.1, 5.1, 5.9, 5.7, 5.2, 5. , 5.2, 5.4, 5.1])

# %%
# Calculer les ECDF



# Tracer tous les ECDF sur le même graphe



# Annotate the plot
plt.legend(('setosa', 'versicolor', 'virginica'), loc='lower right')
_ = plt.xlabel('petal length (cm)')
_ = plt.ylabel('ECDF')

# Display the plot
plt.show()

# %%
Nous avons vu que les hist

# %%
Laquelle des affirmations suivantes est vraie concernant les moyennes et les médianes?

# %% [markdown]
# # La moyenne et la médiane d'un échantillon

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Laquelle des affirmations suivantes est vraie concernant les moyennes et les médianes?

# %% [markdown]
#     Une valeur aberrante peut affecter de manière significative la valeur de la moyenne et de la médiane.
#
#     Une valeur aberrante peut affecter de manière significative la valeur de la moyenne, mais pas la médiane.
#
#     Les moyennes et les médianes sont en général à la fois robustes et aberrantes.
#
#     La moyenne et la médiane sont égales s'il y a un nombre impair de points de données.

# %% [markdown]
# # Outliers

# %% [markdown]
# Points dont la valeur est bien supérieure ou inférieure à
# la plupart des autres données

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Calculer la moyenne de la longeur des pétales  de versicolor

____

# Printer le résultat 

print('I. versicolor:', mean_length_vers, 'cm')

# %%
#idem avec la médiane

# %% [markdown]
# # Centiles, outliers and box plots

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# En statistiques, l’écart interquartile IQR est une mesure de dispersion qui s'obtient en faisant la différence entre le troisième et le premier quartile : EI = Q₃ - Q₁. L'EI est un estimateur statistique robuste

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Dans cet exercice, on va calculer les percentiles de la longueur des pétales des "Iris versicolor"

# %% [markdown]
# Créer "centiles", un tableau NumPy des centiles que vous souhaitez calculer :
#     2,5%
#     25%
#     50%
#     75%
#     97,5%.
#
# Vous pouvez le faire en créant une liste contenant ces int/float et convertissant la liste en un tableau NumPy en utilisant np.array ().
#
# Par exemple, np.array ([30, 50]) créerait un tableau composé des 30e et 50e centiles.
#
# Utilisez np.percentile () pour calculer les centiles de la longueur des pétales à partir des échantillons d'Iris versicolor.

# %%
# Spécifier un tableau de centiles: centiles

centiles = ____

# Calculer les centiles: ptiles_vers

ptiles_vers = 

# Imprimer le résultat

# %% [markdown]
# Pour voir comment les centiles sont liés à l'ECDF, vous allez tracer les centiles des longueurs de pétales d'Iris versicolor que vous avez calculés dans le dernier exercice sur le tracé ECDF que vous avez généré.
#
# Notez que pour garantir que l'axe Y du tracé ECDF reste entre 0 et 1, vous devrez redimensionner le tableau des centiles en conséquence - dans ce cas, en le divisant par 100.

# %%
# Ploter ECDF

# Ajouter des labels


# Superposez les centiles sous forme de "red diamonds".
_ = plt.plot(____, percentiles/100, ____='D', ____='red',
         ____=____)

# Show time

# %% [markdown]
# # Box-and-whisker plot

# %% [markdown]
# Il n'est pas nécessaire de créer un diagramme en boîte pour la longueur des pétales car l'ensemble de données sur l'iris n'est pas trop grand et le  "bee swarme plot" fonctionne correctement. Cependant, il est toujours bon de s'entraîner. Faites une boîte à moustaches des longueurs des pétales d'iris.

# %%
# Créer un plot box avec les paramètres par défaut de Seaborn (utiliser iris_df)

_______

# Étiqueter les axes

_______

# show time

# %% [markdown]
# # Variance et écart-type

# %% [markdown]
# En statistique et en théorie des probabilités, la variance est une mesure de la dispersion des valeurs d'un échantillon ou d'une distribution de probabilité (variabilité).
#
# Elle est égale à la distance quadratique moyenne des données par rapport à leur moyenne

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# En mathématiques, l’écart type est une mesure de la dispersion des valeurs d'un échantillon statistique ou d'une distribution de probabilité. Il est défini comme la racine carrée de la variance ou, de manière équivalente, comme la moyenne quadratique des écarts par rapport à la moyenne

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Calcul de la variance
#
# Il est important d'avoir une certaine compréhension de ce que font les fonctions couramment utilisées.
#
# Dans cet exercice, nous calculerons explicitement la variance de la longueur des pétales d'Iris veriscolor en utilisant les équations présentées plus haut.
#
# Nous utiliserons ensuite np.var () pour vérifier le resultat.

# %% [markdown]
# # C'est le moment d'utiliser les comprehensions de liste vues précédemment

# %%
# Créez un tableau appelé differences qui est la différence entre la longueur des pétales (versicolor_petal_length) et la longueur moyenne des pétales


# Mettre au carré chaque élément dans diff_sq


# Calculer la différence quadratique moyenne


# Calculer la variance en utilisant NumPy: variance_np

# %%
# Calculer la variance: variance


# Printer la racine carrée de la variance


# printer l'écart-type

# %% [markdown]
# # Covariance et le coefficient de corrélation de Pearson

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# la covariance entre deux variables aléatoires est un nombre permettant de quantifier leurs écarts conjoints par rapport à leurs espérances respectives.
#
# ou plus simplement : une mesure de la façon dont deux quantités varient ensemble

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Le coefficient de corrélation de pearson mesure une corrélation linéaire entre deux variables.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Lorsque vous avez créé des graphes de type bee swarme plot, boxplot, ECDF dans les exercices précédents, vous avez comparé les longueurs de pétales de différentes espèces d'iris. Mais que se passe-t-il si vous voulez comparer deux propriétés d'une même espèce?
#
# C'est exactement ce que nous allons faire dans cet exercice. Nous allons faire un diagramme de dispersion des mesures de la longueur et de la largeur des pétales des fleurs d'Iris Anderson versicolor. Si la fleur conserve sa proportion à mesure qu'elle grandit, nous nous attendrions à ce que la longueur et la largeur soient corrélées.

# %% [markdown]
# Utilisez plt.plot () avec les arguments de mots clés appropriés pour créer un nuage de points de la longueur des pétales versicolor (axe x) en fonction de la largeur des pétales (axe y).

# %%
versicolor_petal_width = np.array([1.4, 1.5, 1.5, 1.3, 1.5, 1.3, 1.6, 1. , 1.3, 1.4, 1. , 1.5, 1. ,
       1.4, 1.3, 1.4, 1.5, 1. , 1.5, 1.1, 1.8, 1.3, 1.5, 1.2, 1.3, 1.4,
       1.4, 1.7, 1.5, 1. , 1.1, 1. , 1.2, 1.6, 1.5, 1.6, 1.5, 1.3, 1.3,
       1.3, 1.2, 1.4, 1.2, 1. , 1.3, 1.2, 1.3, 1.3, 1.1, 1.3])

# %%
# Faire un scatter plot



# mettre des labels sur les axes



# show time

# %%
Etudier les graphes suivants

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Qui a, respectivement,

    la variance la plus élevée de la variable x,

    la covariance la plus élevée,

    une covariance négative?

# %% [markdown]
# La covariance peut être calculée à l'aide de la fonction Numpy np.cov (). Par exemple, nous avons deux ensembles de données x et y, np.cov (x, y) renvoie un tableau 2D où les entrées [0,1] et [1,0] sont les covariances. L'entrée [0,0] est la variance des données en x et l'entrée [1,1] est la variance des données en y. Ce tableau de sortie 2D est appelé matrice de covariance

# %% [markdown]
# Utilisez np.cov () pour calculer la matrice de covariance pour la longueur du pétale (versicolor_petal_length) et la largeur (versicolor_petal_width) de Iirs versicolor.

# %%
# Calculer la matrice de covariance: covariance_matrix


# printer la matrice de covariance


# Extraire la covariance de la longueur et de la largeur des pétales: petal_cov


# printer la covariance longueur / largeur

# %% [markdown]
# # Partie facultative

# %% [markdown]
# Le problème de Monty Hall
#
# L'exposé du problème est plutôt simple. Imaginez un jeu télévisé où il y a trois portes sur le plateau de jeu. Seule une de ces portes cache un trésor. Il n'y a rien derrière les deux autres portes. Rien ne permet de savoir quelle porte cache le trésor.
#
# La tâche du joueur consiste à choisir parmi les trois portes celle qu'il veut ouvrir. Il aura droit au trésor s'il choisit la bonne porte, et rien sinon. Pour faire son choix, il n'a aucune information. Il doit donc simplement s'en remettre au hasard.
#
# Jusqu'ici, le problème n'a rien de remarquable. Mais il y a un twist ! Une fois que le joueur a fait son choix, mais avant d'ouvrir la porte, le présentateur élimine, parmi les deux portes non choisies, une porte qui ne contient pas de trésor. Si les deux portes restantes ne contiennent rien, le présentateur élimine simplement une d'entre elles au hasard.
#
# Le joueur doit alors faire un nouveau choix. Il peut soit choisir d'ouvrir la première porte qu'il avait choisie, soit changer pour la porte non éliminée par le présentateur. La question est, qu'a-t-il intérêt à faire ? Réfléchissez-y. Vous n'avez en principe pas besoin de connaissances poussées en probabilités pour résoudre ce problème. Que feriez-vous ?

# %% [markdown]
# Pouvez-vous réaliser une simulation de ce problème à l'aide d'une fonction ? Et vérifier s'il est plus intéressant ou non de changer de porte?

# %%
# Utilise l'horloge système pour initialiser le générateur de 
# nombres pseudo-aléatoires.
from random import randint, seed
seed()

def play_game(strategie):
    '''Simule une partie du jeu Monty Hall.
    
    Cette fonction simule le choix de la porte par le participant, 
    l'élimination d'une mauvaise porte par le présentateur, et le 
    choix final. Elle ne retourne que le résultat de la partie, parce 
    que nous n'aurons besoin que du résultat pour effectuer nos calculs.
    
    Args:
        strategie (Strategie): La stratégie du joueur
        
    Returns:
        bool: Le joueur a-t-il gagné?'''
    
    pass
